# %%
# import pandas library
import pandas as pd
import numpy as np

# %%
# \ need to be replaced with / in file path
path = "//elnt118/AGRDSRD/AT/ApplicationsData/HistoricalData/DriftStudyParticleSize/AllData_Stats.xlsx"

# %%
df = pd.read_excel(path)

# %%
df.head()
# Out:
#   Sample Adjuvant 1 Adjuvant 2 Rep     Nozzle Spray Pressure Nozzle Position  \
# 0  Water        NaN        NaN   2  AIXR11003         40 psi        TRAVERSE
# 1  Water        NaN        NaN   1  AIXR11003         40 psi        TRAVERSE
# 2  Water        NaN        NaN   2    XR11003         40 psi        TRAVERSE
# 3  Water        NaN        NaN   1    XR11003         40 psi        TRAVERSE
# 4  Water        NaN        NaN   3   XR110025         40 psi        TRAVERSE
#
#         Time of meas.  % Fines <150 um    RS  ...   2060   2460   2940  3500  \
# 0 2022-09-14 15:50:41            10.64  1.44  ...  100.0  100.0  100.0   100
# 1 2022-09-14 15:50:00            10.51  1.43  ...  100.0  100.0  100.0   100
# 2 2022-09-14 15:37:53            34.59  1.42  ...  100.0  100.0  100.0   100
# 3 2022-09-14 15:37:04            36.07  1.42  ...  100.0  100.0  100.0   100
# 4 2022-09-14 15:35:54            40.23  1.38  ...  100.0  100.0  100.0   100
#
# ...

# %%
df.columns
# Out:
# Index([                 'Sample',              'Adjuvant 1',
#                     'Adjuvant 2',                     'Rep',
#                         'Nozzle',          'Spray Pressure',
#                'Nozzle Position',           'Time of meas.',
#                '% Fines <150 um',                      'RS',
#                            'd10',                     'd50',
#                            'd90',                 'Copt /%',
#                  'Meas. Comment',               'Calc Mode',
#                      'Size Bins',                       0.5,
#                               18,                        22,
#                               26,                        30,
#                               36,                        44,
#                               52,                        62,
#                               74,                        86,
#                              100,                       120,
# ...

# %%
df.dtypes
# Out:
# Sample                             object
# Adjuvant 1                         object
# Adjuvant 2                         object
# Rep                                object
# Nozzle                             object
# Spray Pressure                     object
# Nozzle Position                    object
# Time of meas.              datetime64[ns]
# % Fines <150 um                   float64
# RS                                float64
# d10                               float64
# d50                               float64
# d90                               float64
# Copt /%                           float64
# Meas. Comment                      object
# Calc Mode                          object
# Size Bins                          object
# 0.5                                 int64
# 18                                float64
# 22                                float64
# 26                                float64
# 30                                float64
# ...

# %%
df.describe()
# Out:
#        % Fines <150 um            RS           d10           d50  \
# count     11810.000000  11810.000000  11810.000000  11810.000000
# mean         25.020419      1.322029    126.035686    277.930952
# std          18.141674      1.391399     51.475878    125.755346
# min           0.550000      0.650000      5.500000     38.190000
# 25%           7.382500      1.180000     85.250000    176.732500
# 50%          25.060000      1.280000    103.870000    216.225000
# 75%          38.047500      1.360000    168.167500    394.125000
# max          99.870000     82.210000    438.470000    948.360000
#
#                 d90       Copt /%      0.5            18            22  \
# count  11810.000000  11810.000000  11810.0  11810.000000  11810.000000
# mean     484.783974     20.128044      0.0      0.459211      0.489908
# std      211.009527    824.634610      0.0      1.458826      1.482942
# min        6.510000      0.100000      0.0      0.000000      0.000000
# ...

# %%
df.describe(include="all")
# Out:
# C:\Users\jo5117\AppData\Local\Temp/ipykernel_32532/1985922364.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include="all")
#        Sample Adjuvant 1 Adjuvant 2      Rep  Nozzle Spray Pressure  \
# count   11810         87         16  11435.0   11529          11731
# unique   1977          2          2     30.0     109             52
# top     WATER         SC        EFW      1.0  XR8002         40 psi
# freq     1915         44          8   3487.0    3732           8788
# first     NaN        NaN        NaN      NaN     NaN            NaN
# last      NaN        NaN        NaN      NaN     NaN            NaN
# mean      NaN        NaN        NaN      NaN     NaN            NaN
# std       NaN        NaN        NaN      NaN     NaN            NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11810 entries, 0 to 11809
# Data columns (total 55 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Sample                   11810 non-null  object
#  1   Adjuvant 1               87 non-null     object
#  2   Adjuvant 2               16 non-null     object
#  3   Rep                      11435 non-null  object
#  4   Nozzle                   11529 non-null  object
#  5   Spray Pressure           11731 non-null  object
#  6   Nozzle Position          11736 non-null  object
#  7   Time of meas.            11810 non-null  datetime64[ns]
#  8   % Fines <150 um          11810 non-null  float64
#  9   RS                       11810 non-null  float64
#  10  d10                      11810 non-null  float64
#  11  d50                      11810 non-null  float64
#  12  d90                      11810 non-null  float64
# ...
